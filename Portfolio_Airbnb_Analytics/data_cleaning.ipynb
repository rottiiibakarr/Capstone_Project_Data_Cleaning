# %%
import pandas as pd

# %%
# Inisialisasi Data
df = pd.read_csv('data_raw/Airbnb_Cleaned_Europe_Dataset.csv', sep=',')
df.columns = df.columns.str.strip() # Menghapus whitespaces pada kolom/header tabel (jika ada)

# Mengecek jumlah baris apakah terdapat duplikat atau tidak sebelum proses cleaning
print(f'Total baris duplikat: {df.duplicated().sum()}')
# Out:
# Total baris duplikat: 0

# %%
# Mengubah Format 
# Mengubah Format Jumlah Desimal 
df['Price'] = df['Price'].round(2)
df['City Center (km)'] = df['City Center (km)'].round(2)
df['Metro Distance (km)'] = df['Metro Distance (km)'].round(2)
df['Attraction Index'] = df['Attraction Index'].round(2)
df['Normalised Attraction Index'] = df['Normalised Attraction Index'].round(2)
df['Restraunt Index'] = df['Restraunt Index'].round(2)
df['Normalised Restraunt Index'] = df['Normalised Restraunt Index'].round(2)

# Mengubah Format Tipe Data 
df['Person Capacity'] = df['Person Capacity'].astype(int)
df['Cleanliness Rating'] = df['Cleanliness Rating'].astype(int)
df['Guest Satisfaction'] =df['Guest Satisfaction'].astype(int)

# Mengubah Format Setiap Kata menjadi Huruf Kapital
df['Room Type'] = df['Room Type'].str.title()

df.head()
# Out:
#         City   Price      Day     Room Type  Shared Room  Private Room  \
# 0  Amsterdam  194.03  Weekday  Private Room        False          True
# 1  Amsterdam  344.25  Weekday  Private Room        False          True
# 2  Amsterdam  264.10  Weekday  Private Room        False          True
# 3  Amsterdam  433.53  Weekday  Private Room        False          True
# 4  Amsterdam  485.55  Weekday  Private Room        False          True
#
#    Person Capacity  Superhost  Multiple Rooms  Business  Cleanliness Rating  \
# 0                2      False               1         0                  10
# 1                4      False               0         0                   8
# 2                2      False               0         1                   9
# 3                4      False               0         1                   9
# 4                2       True               0         0                  10
#
#    Guest Satisfaction  Bedrooms  City Center (km)  Metro Distance (km)  \
# ...

# %%
# Pengecekan Logika
# Pengecekan Konsistensi Tipe Kamar
df['Shared Room'] = df['Room Type'] == 'Shared Room'
df['Private Room'] = df['Room Type'] == 'Private Room'

# Pengecekan Batas Maksimal Rating
df['Cleanliness Rating'] = df['Cleanliness Rating'].clip(lower=0, upper=10)
df['Guest Satisfaction'] = df['Guest Satisfaction'].clip(lower=0, upper=100)

df.head()
# Out:
#         City   Price      Day     Room Type  Shared Room  Private Room  \
# 0  Amsterdam  194.03  Weekday  Private Room        False          True
# 1  Amsterdam  344.25  Weekday  Private Room        False          True
# 2  Amsterdam  264.10  Weekday  Private Room        False          True
# 3  Amsterdam  433.53  Weekday  Private Room        False          True
# 4  Amsterdam  485.55  Weekday  Private Room        False          True
#
#    Person Capacity  Superhost  Multiple Rooms  Business  Cleanliness Rating  \
# 0                2      False               1         0                  10
# 1                4      False               0         0                   8
# 2                2      False               0         1                   9
# 3                4      False               0         1                   9
# 4                2       True               0         0                  10
#
#    Guest Satisfaction  Bedrooms  City Center (km)  Metro Distance (km)  \
# ...

# %%
# Mengecek jumlah duplikat setelah dibulatkan
print(f'Duplikat setelah proses cleaning: {df.duplicated().sum()}')

# Menghapus baris yang duplikat
df.drop_duplicates(inplace=True)

# Pengecekan, apakah terdapat nilai yang masih tidak sesuai (contoh nilai minus)
df.describe()
# Out:
# Duplikat setelah proses cleaning: 40
#               Price  Person Capacity  Multiple Rooms      Business  \
# count  41674.000000     41674.000000    41674.000000  41674.000000
# mean     260.127427         3.237822        0.295412      0.340692
# std      279.515250         1.299470        0.456233      0.473948
# min       34.780000         2.000000        0.000000      0.000000
# 25%      144.020000         2.000000        0.000000      0.000000
# 50%      203.870000         3.000000        0.000000      0.000000
# 75%      297.370000         4.000000        1.000000      1.000000
# max    18545.450000         6.000000        1.000000      1.000000
#
#        Cleanliness Rating  Guest Satisfaction      Bedrooms  City Center (km)  \
# count        41674.000000        41674.000000  41674.000000      41674.000000
# mean             9.441786           93.099103      1.166387          2.680346
# std              0.889408            8.143599      0.638029          1.997320
# ...

# %%
# Menyimpan File ke CSV
df.to_csv('data_clean/clean_airbnb_data.csv', index=False)
