# %%
import pandas as pd

# %%
df = pd.read_csv('data_raw/DataCoSupplyChainDataset.csv', encoding='latin1')
df.columns = df.columns.str.strip()

# %%
# Mengecek Duplikat, Jumlah Data pada Dataset, dan Info
print(f'Total baris duplikat: {df.duplicated().sum()}')
df.drop_duplicates(inplace=True)
print(f'Total baris setelah menghapus duplikat: {df.duplicated().sum()}')

print(f'Total data pada dataset Attendance: {df.shape} [baris, kolom]')

df.info()
# Out:
# Total baris duplikat: 0
# Total baris setelah menghapus duplikat: 0
# Total data pada dataset Attendance: (180519, 53) [baris, kolom]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
# ...

# %%
# Data Cleaning
# Bagian Customer 
state_mapping = {
    'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 
    'CO': 'Colorado', 'CT': 'Connecticut', 'DC': 'District of Columbia', 
    'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 
    'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 
    'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'MA': 'Massachusetts', 
    'MD': 'Maryland', 'MI': 'Michigan', 'MN': 'Minnesota', 'MO': 'Missouri', 
    'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota', 
    'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada', 'NY': 'New York', 
    'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 
    'PR': 'Puerto Rico', 'RI': 'Rhode Island', 'SC': 'South Carolina', 
    'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia', 
    'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia',
    
    # Memperbaiki data yang salah berdasarkan kodepos
    '91732': 'California', # Zip code untuk area El Monte, CA
    '95758': 'California'  # Zip code untuk area Elk Grove, CA
}

customer_city_fixes = {
    # --- Puerto Rico (Memperbaiki Aksen Spanyol) ---
    'Bayamon': 'Bayamón',
    'Canovanas': 'Canóvanas',
    'Juana Diaz': 'Juana Díaz',
    'Manati': 'Manatí',
    'Mayaguez': 'Mayagüez',
    'San Sebastian': 'San Sebastián',
    
    # --- Amerika Serikat (Memperbaiki Tanda Baca) ---
    'O Fallon': "O'Fallon",
    'Opa Locka': 'Opa-locka',
    'Wilkes Barre': 'Wilkes-Barre',
    'Fond Du Lac': 'Fond du Lac'
}

df['Customer Country'] = df['Customer Country'].replace({'EE. UU.': 'United States of America'})

df['Customer State'] = df['Customer State'].map(state_mapping).fillna(df['Customer State'])

df['Customer City'] = df['Customer City'].astype(str).str.replace(r'\s+', ' ', regex=True).str.strip()
df['Customer City'] = df['Customer City'].replace(customer_city_fixes)
df['Customer City'] = df['Customer City'].replace({'CA': 'Unknown City'})

df['Customer Lname'] = df['Customer Lname'].fillna('Unknown')

print("Nama negara pada dataset: ")
print(sorted(df['Customer Country'].unique()))

print("\n")

print("Daftar nama negara bagian Amerika Serikat pada dataset: ")
print(sorted(df['Customer State'].unique()))

print("\n")

print("Daftar nama kota pada dataset: ")
print(sorted(df['Customer City'].unique()))

print("\n")

print("Jenis Customer pada dataset: ")
print(sorted(df['Customer Segment'].unique()))

print("\n")

# Mengecek Missing Values (data hilang) pada kolom dataset
print(f"Jumlah data yang hilang pada kolom Costumer Country di dataset: {df['Customer Country'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer State di dataset: {df['Customer State'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer City di dataset: {df['Customer City'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Zipcode di dataset: {df['Customer Zipcode'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Street di dataset: {df['Customer Street'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Segment di dataset: {df['Customer Segment'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Email di dataset: {df['Customer Email'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer ID di dataset: {df['Customer Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Fname di dataset: {df['Customer Fname'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Costumer Lname di dataset: {df['Customer Lname'].isna().sum()}") # Sebelumnya terdapat 8 missing values
print(f"Jumlah data yang hilang pada kolom Costumer Password di dataset: {df['Customer Password'].isna().sum()}")

print("\n")

df.head(10)
# Out:
# Nama negara pada dataset:
# ['Puerto Rico', 'United States of America']
#
#
# Daftar nama negara bagian Amerika Serikat pada dataset:
# ['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'Montana', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']
#
#
# Daftar nama kota pada dataset:
# ...

# %%
# Data Cleaning
# Bagian Order 

order_state_fixes = {
    # =========================================================
    # AMERICA (NORTH, CENTRAL, SOUTH)
    # =========================================================

    # --- North America ---
    # === Canada ===
    'Columbia brit nica': 'British Columbia',
    'Nueva Escocia': 'Nova Scotia',
    
    # === United States of America ===
    'Nueva York': 'New York',
    'Nueva Jersey': 'New Jersey',
    'Nuevo Hampshire': 'New Hampshire',
    'Nuevo México': 'New Mexico',
    'Nuevo M xico': 'New Mexico',
    'Carolina del Norte': 'North Carolina',
    'Carolina del Sur': 'South Carolina',
    'Dakota del Norte': 'North Dakota',
    'Dakota del Sur': 'South Dakota',
    'Distrito de Columbia': 'District of Columbia',
    'Virginia Occidental': 'West Virginia',
    'Columbia Británica': 'British Columbia',
    'Nueva Escocia': 'Nova Scotia',
    'Oreg n': 'Oregon',
    'Pensilvania': 'Pennsylvania',
    'Misisipi': 'Mississippi', 
    'Misuri': 'Missouri',
    'Luisiana': 'Louisiana',
    'Terranova': 'Newfoundland and Labrador',

    # --- Central America & Caribbean ---
    # === Mexico ===
    'Nuevo Le n': 'Nuevo León',
    'M xico': 'México',
    'Michoac n': 'Michoacán',
    'Yucat n': 'Yucatán',
    'Quer taro': 'Querétaro',
    'San Luis Potos': 'San Luis Potosí',

    # === El Salvador ===
    'Cuscatl n': 'Cuscatlán',

    # === Belize ===
    'Distrito de Cayo': 'Cayo District',
    
    # === Dominican Republic ===
    'Monse or Nouel': 'Monseñor Nouel',
    'San Pedro de Macoris': 'San Pedro de Macorís',
    'San Pedro de Macor s': 'San Pedro de Macorís',

    # === Honduras ===
    'Francisco Moraz n': 'Francisco Morazán', # Department
    'Cort s': 'Cortés',
    'Col n': 'Colón',
    'Atl ntida': 'Atlántida',

    # === Panama === 
    'Col n': 'Colón',
    'Chiriqu': 'Chiriquí', 
    'Panam': 'Panama',
    
    # === Cuba ===
    'Holgu n': 'Holguín',
    'Pinar del R o': 'Pinar del Río',
    'Camag ey': 'Camagüey',
    'Ciego de vila': 'Ciego de Ávila',
    'Sancti Sp ritus': 'Sancti Spíritus',
    'Guant namo': 'Guantánamo',
    'Santiago de Cuba': 'Santiago de Cuba',

    # === Nicaragua ===
    'Estel': 'Estelí',

    # --- South American ---
    # === Colombia === 
    'Antioqu a': 'Antioquia',
    'Quind o': 'Quindío',
    'Nari o': 'Nariño',
    'Atl ntico': 'Atlántico',
    'Bogot': 'Bogotá',
    'Boyac': 'Boyacá',
    'Caquet': 'Caquetá', 
    'Choc': 'Chocó',
    'Departamento Atl ntico': 'Atlántico',
    'Norte de Santander': 'North Santander',
    'Valle del Cauca': 'Valle del Cauca',

    # === Ecuador === 
    'Los R os': 'Los Ríos', 
    'Manab': 'Manabí',
    
    # === Venezuela ===
    'Anzo tegui': 'Anzoátegui',
    'Bol var': 'Bolívar',
    'M rida': 'Mérida',
    'T chira': 'Táchira',
    'Regi n Capital': 'Capital Region',
    'Gu rico': 'Guárico',
    'San Crist bal': 'San Cristóbal',
    'Nueva Esparta': 'Nueva Esparta',

    # === Bolivia ===
    'Potos': 'Potosí',

    # === French Guiana ===
    'Demerara-Berbice Superior': 'Upper Demerara-Berbice',
    'Franz sisch-Guayana': 'French Guiana',
    
    # === Brazil ===
    'Bah a': 'Bahía',
    'Goi s': 'Goiás',
    'Amap': 'Amapá',
    'Mara n': 'Maranhão',
    'Río de Janeiro': 'Rio de Janeiro',
    'R o de Janeiro': 'Rio de Janeiro',
    'Río Grande del Norte': 'Rio Grande do Norte',
    'R o Grande del Norte': 'Rio Grande do Norte',
    'Mato Grosso del Sur': 'Mato Grosso do Sul',
    'S o Paulo': 'São Paulo',
    'Esp ritu Santo': 'Espírito Santo',
    'Para ba': 'Paraíba',
    'Cear': 'Ceará',
    'Par': 'Pará',
    'Paran': 'Paraná',
    'Piau': 'Piauí',
    'Rond nia': 'Rondônia',
    
    # === Paraguay ===
    'Asunci n': 'Asunción',

    # === Uruguay === 
    'Paysand': 'Paysandú',

    # === Chile ===
    'B o-B o': 'Bío-Bío',
    'Magallanes y Ant rtica Chilena': 'Magallanes and Chilean Antarctica',
    'Valpara so': 'Valparaíso',
    'Santiago de Chile': 'Santiago',
    'Tarapac': 'Tarapacá',

    # === Peru ===
    'Jun n': 'Junín',
    'Lima (ciudad)': 'Lima',
    'Mara n': 'Marañón',
    
    # === Argentina ===
    'C rdoba': 'Córdoba',
    'Neuqu n': 'Neuquén',
    'Entre R os': 'Entre Ríos',
    'R os': 'Río Tala',
    'Río Negro': 'Rio Negro',
    'R o Negro': 'Rio Negro',
    'Santiago del Estero': 'Santiago del Estero',
    'Buenos Aires (provincia)': 'Buenos Aires',

    # =========================================================
    # EUROPEAN
    # =========================================================

    # === Portugal === 
    'Set bal': 'Setúbal',

    # === Spain ===
    'Catalu a': 'Catalonia',
    'Cataluña': 'Catalonia',
    'Andaluc a': 'Andalusia',
    'Andalucía': 'Andalusia',
    'Le n': 'León',
    'Castilla y Le n': 'Castile and León',
    'Castilla and León': 'Castile and León',
    'Islas Baleares': 'Illes Balears',
    'Pa s Vasco': 'Basque Country',
    
    # === Ireland ===
    'Dubl n': 'Dublin',
    'Dubl n del Sur': 'South Dublin',

    # === United Kingdom (UK) ===
    'Gales': 'Wales',
    'Inglaterra': 'England',
    'Escocia': 'Scotland',

    # === Finland === 
    'Finlandia del Sudoeste': 'Southwest Finland',
    
    # === Sweden ===
    'Estocolmo': 'Stockholm',
    'Escania': 'Scania',
    'S dermanland': 'Södermanland',
    'V rmland': 'Värmland',
    'V stra G taland': 'Västra Götaland',
    
    # === France ===
    'Auvernia': 'Auvergne',
    'Auvernia-R dano-Alpes': 'Auvergne-Rhône-Alpes',
    'Alsacia-Champa a-Ardenas-Lorena': 'Grand Est',
    'Aquitania-Lemos n-Poitou-Charentes': 'Nouvelle-Aquitaine',
    'Borgo a-Franco Condado': 'Bourgogne-Franche-Comté',
    'Borgoña-Franco Condado': 'Bourgogne-Franche-Comté',
    'Breta a': 'Brittany',
    'Bretaña': 'Brittany',
    'Centro-Valle de Loira': 'Centre-Val de Loire',
    'Norte-Paso de Calais-Picard a': 'Hauts-de-France',
    'Normand a': 'Normandy',
    'Normandía': 'Normandy',
    'Isla de Francia': 'Île-de-France',
    'Pa ses del Loira': 'Pays de la Loire',
    'Países del Loira': 'Pays de la Loire',
    'Provenza-Alpes-Costa Azul': "Provence-Alpes-Côte d'Azur",
    'Corse': 'Corsica',
    'Languedoc-Rosell n-Mediod a-Pirineos': 'Occitanie',
    'Guadalupe': 'Guadeloupe',           
    'Martinica': 'Martinique',

    # === Belgium ===
    'Flanders Occidental': 'West Flanders',
    'Flanders Oriental': 'East Flanders',
    'Amberes': 'Antwerp',
    'Bruselas': 'Brussels',
    'Brabante Flamenco': 'Flemish Brabant',
    'Lieja': 'Liège',
    'Henao': 'Hainaut',

    # === Netherlands ===
    'Holanda Meridional': 'South Holland',
    'Holanda Septentrional': 'Noord-Holland',
    'G eldres': 'Gelderland',
    'Brabante Septentrional': 'North Brabant',
    'Frisia': 'Friesland',
    'Limburgo': 'Limburg',

    # === Luxembourg === 
    'Luxemburgo': 'Luxembourg',

    # === Switzerland ===
    'Zúrich': 'Zürich',
    'Z rich': 'Zürich',
    'Basilea-Ciudad': 'Basel-Stadt',
    'Berna': 'Bern',
    'Ginebra': 'Geneva',
    'Lucerna': 'Lucerne',
    'San Galo': 'St. Gallen',
    
    # === Italy ===
    'Lombard a': 'Lombardy',
    'Emilia-Roma a': 'Emilia-Romagna',
    'Cerde a': 'Sardinia',
    'Umbr a': 'Umbria',
    'Abruzos': 'Abruzzo',
    'Lacio': 'Lazio',
    'Piamonte': 'Piedmont',
    'V neto': 'Veneto',
    
    # === Denmark ===
    'Dinamarca Meridional': 'Region of Southern Denmark',
    'Zelanda': 'Zealand',
    'Selandia': 'Zealand',
    'Jutlandia Central': 'Central Denmark Region',

    # === Germany ===
    'Baden-Wurtemberg': 'Baden-Württemberg',
    'Baja Sajonia': 'Lower Saxony',
    'Berl n': 'Berlin',
    'Bavaria': 'Bavaria',
    'Brandenburgo': 'Brandenburg',
    'Hamburgo': 'Hamburg',
    'Sajonia': 'Saxony',
    'Sajonia-Anhalt': 'Saxony-Anhalt',
    'Turingia': 'Thuringia',
    'Renania-Palatinado': 'Rheinland-Pfalz',
    'Renania del Norte-Westfalia': 'North Rhine-Westphalia',
    'Mecklemburgo-Pomerania Occidental': 'Mecklenburg-Vorpommern',

    # === Poland ===
    'Gran Polonia': 'Greater Poland',
    'Polonia Menor': 'Lesser Poland',
    'Podlaquia': 'Podlaskie',

    # === Austria ===
    'Alta Austria': 'Upper Austria',
    'Carintia': 'Carinthia',
    'Salzburgo': 'Salzburg',
    'Stiria': 'Styria',
    'Viena': 'Vienna',

    # === Czechia ===
    'Hradec Kr lov': 'Hradec Králové',
    'st nad Labem': 'Ústí nad Labem',
    'Pilsen': 'Plzeň',
    'Praga': 'Prague',
    
    # === Slovakia ===
    'Bansk Bystrica': 'Banská Bystrica',
    'ilina': 'Žilina',
    'Bansk Bystrica': 'Banská Bystrica',

    # === Slovenia ===
    'Liubliana': 'Ljubljana',
    
    # === Hungary ===
    'B k s': 'Békés',
    'Hajd -Bihar': 'Hajdú-Bihar',
    'Gy?r': 'Győr',

    # === Croatia ===
    'Zagrebacka': 'Zagrebačka',
    'Split-Dalmacia': 'Split-Dalmatia',
    'Osjecko-Baranjska': 'Osijek-Baranja',

    # === Bulgaria ===
    'Sof a-Ciudad': 'Sofia',

    # === Bosnia and Herzegovina ===
    'Federaci n de Bosnia y Herzegovina': 'Federation of Bosnia and Herzegovina',

    # === Albania ===
    'Durr s': 'Durrës',
    'Shkod r': 'Shkodër',
    'Vlor': 'Vlorë',

    # === Lithuania ===
    'Klaip?da': 'Klaipėda',
    'iauliai': 'Šiauliai',
    'Vilna': 'Vilnius',
    
    # === Belarus ===
    'G mel': 'Gomel',
    
    # === Russia ===
    'Arj nguelsk': 'Arkhangelsk',
    'Bashkortost n': 'Bashkortostan',
    'Daguest n': 'Dagestan',
    'Astrac n': 'Astrakhan',
    'B lgorod': 'Belgorod',
    'Cheli binsk': 'Chelyabinsk',
    'N vgorod': 'Novgorod',
    'Vlad mir': 'Vladimir',
    'Vor nezh': 'Voronezh',
    'Mosc': 'Moscow',
    'Kaliningrado': 'Kaliningrad',
    'St vropol': 'Stavropol',
    'Yevrey': 'Jewish Autonomous Oblast',

    # === Georgia === 
    'Tiflis': 'Tbilisi',
    'Imericia': 'Imereti',

    # === Ukraine ===
    'J rkov': 'Kharkiv',
    'Tern pil': 'Ternopil',
    'V nnytsia': 'Vinnytsia',
    'Zhyt myr': 'Zhytomyr',
    'Jers n': 'Kherson',
    'Zaporiyia': 'Zaporizhzhia',
    'Volinia': 'Volyn',

    # === Moldova ===
    'Chisin u': 'Chișinău',
    
    # === Romania ===
    'V lcea': 'Vâlcea',
    'Bra?ov': 'Brașov',
    'Constanza': 'Constanța',

    # =========================================================
    # AFRICA
    # =========================================================

    # === Morocco === 
    'Fez-Bulm n': 'Fès-Boulemane',
    'Fas Bulman': 'Fès-Boulemane',
    'T nger-Tetu n': 'Tangier-Tétouan',
    'Chau a-Uardiga': 'Chaouia-Ouardigha',
    'Garb-Chrarda-Beni Hsen': 'Gharb-Chrarda-Beni Hssen',
    'Rabat-Sal -Zemur-Zaer': 'Rabat-Salé-Zemmour-Zaer',
    'Gran Casablanca': 'Grand Casablanca',
    'Mequinez-Tafilalet': 'Meknès-Tafilalet',
    'Sus-Masa-Draa': 'Souss-Massa-Drâa',
    'Taza-Alhucemas-Taunat': 'Taza-Al Hoceima-Taounate',

    # === Western Sahara ===
    'El Aai n': 'El Aaiún',
    
    # === Algeria ===
    'Or n': 'Oran',                  
    'Bug a': 'Bejaia',
    'B char': 'Béchar',
    'Constantina': 'Constantine',

    # === Tunisia ===
    'T nez': 'Tunis',

    # === Libya ===
    'Bengasi': 'Benghazi',

    # === Egypt ===
    'Alejandr a': 'Alexandria',
    'Alejandría': 'Alexandria',
    'Fay n': 'Al Fayyum',                
    'Puerto Sa d': 'Port Said',
    'Bursaid': 'Port Said',
    'El Cairo': 'Cairo',
    'Mar Rojo': 'Red Sea Governorate',
    'Kafr el Sheij': 'Kafr el-Sheikh',

    # === Benin ===
    'Ou m': 'Ouémé',

    # === Angola ===
    'Bi': 'Bié',

    # === Burundi ===
    'Buyumbura Mairie': 'Bujumbura Mairie',

    # === Côte d'Ivoire ===
    'Vall e du Bandama': 'Vallée du Bandama',

    # === Djibouti ===
    'Yibuti': 'Djibouti',

    # Ghana
    'Gran Accra': 'Greater Accra',

    # === Guinea ===
    'Nz r kor': 'Nzérékoré',

    # === Guinea-Bissau ===
    'Bis u': 'Bissau',

    # === Niger === 
    'N ger': 'Niger',

    # === Sudan ===
    'Jartum': 'Khartoum',
    'Nilo Blanco': 'White Nile',

    # === South Sudan ===
    'Ecuatoria Central': 'Central Equatoria',

    # === Senegal ===
    'Thi s': 'Thiès',

    # === Democratic Republic of Congo ===
    'quateur': 'Équateur',
    'Bajo Congo': 'Kongo Central',
    'Kasai Occidental': 'Kasai-Occidental',
    'Kasai Oriental': 'Kasai-Oriental',
    'Kivu del Sur': 'South Kivu',
    'Provincia Oriental': 'Orientale Province',
    'quateur': 'Équateur',

    # Togo
    'Mar tima': 'Maritime Region',

    # === Zimbabwe ===
    'Mashonalandia Occidental': 'Mashonaland West',

    # === South Africa ===
    'Cabo Occidental': 'Western Cape', 
    'Cabo Oriental': 'Eastern Cape',
    'Estado Libre': 'Free State',

    # === No General Africa ===
    'Gran Valle del Rift': 'Great Rift Valley',

    # =========================================================
    # ASIA (Central, West, East, South, Southeast)
    # =========================================================

    # Central Asia
    # === Kazakhstan ===
    'Kostan i': 'Kostanay',
    'Ciudad de Almat': 'Almaty',
    'Ciudad de Almaty': 'Almaty',
    'Karagand': 'Karaganda',
    'Astan': 'Astana',

    # === Uzbekistan === 
    'Namang n': 'Namangan',          
    'Andij n': 'Andijan',            
    'Surjandar n': 'Surxondaryo',
    'Kashkadar': 'Qashqadaryo',

    # === Turkmenistan ===
    'Asjabad': 'Ashgabat',

    # West Asia (Middle East)
    # === Turkey ===
    'Bing l': 'Bingöl',
    'D zce': 'Düzce',                
    'K tahya': 'Kütahya',
    'Estambul': 'Istanbul',
    'anakkale': 'Çanakkale',
    'Kahramanmara?': 'Kahramanmaraş',
    'Trebisonda': 'Trabzon',

    # === Azerbaijan === 
    'Baki': 'Baku',

    # === Iran ===
    'Juzest n': 'Khuzestan',          
    'Isfah n': 'Isfahan',            
    'Hamad n': 'Hamedan',            
    'Teher n': 'Tehran',
    'Guil n': 'Gīlān',              
    'Zany n': 'Zanjan',              
    'Sist n y Baluchist n': 'Sistan and Baluchestan',
    'Mazandar n': 'Māzandarān',      
    'Qazv n': 'Qazvin',              
    'Golest n': 'Golestán',          
    'Semn n': 'Semnan',              
    'Hormozg n': 'Hormozgān',
    'Joras n Razav': 'Khorasan Razavi',
    'Joras n del Sur': 'South Khorasan',

    # === Iraq === 
    'N nive': 'Nineveh',
    'Kurdist n': 'Kurdistan',
    'Bagdad': 'Baghdad',
    'Basora': 'Basra',
    'Di Car': 'Dhi Qar',
    'Diala': 'Diyala',
    'Cadisia': 'Al-Qadisiyyah',
    'Saladino': 'Saladin',
    'Mesena': 'Maysan',
    'Babilonia': 'Babil',

    # === Lebanon ===
    'L bano del Norte': 'North Lebanon',

    # === Jordan ===
    'Am n': 'Amman',

    # === Israel === 
    'Jerusal n': 'Jerusalem', 

    # === Saudi Arabian === 
    'Jiz n': 'Jizan',
    'Meca': 'Mecca',
    'Riad': 'Riyadh',

    # United Arab Emirates
    'Ajm n': 'Ajmān',

    # === Oman === 
    'Mascate': 'Muscat',

    # East Asia
    # === Mongolia ===
    'Ulán Bator': 'Ulaanbaatar',     
    'Ul n Bator': 'Ulaanbaatar',
    
    # === China ===
    'Pek n': 'Peking',
    'Pekín': 'Beijing',
    'Peking': 'Beijing',
    'Shangh i': 'Shanghai',
    'Shanghái': 'Shanghai',
    'Mongolia Interior': 'Inner Mongolia',
    
    # === Taiwan ===
    'Taip i': 'Taipei',
    
    # === South Korea ===
    'Se l': 'Seoul',
    'Seúl': 'Seoul',
    'Chungcheong del Sur': 'South Chungcheong',

    # === Japan ===
    'Tokio': 'Tokyo',
    
    # South Asia
    # === Bangladesh ===
    'Daca': 'Dhaka',
    
    # === India ===
    'Rajast n': 'Rajasthan',
    'Bengala Occidental': 'West Bengal',
    'Capital Nacional': 'National Capital Territory',
    'Guyarat': 'Gujarat',
    'Punyab': 'Punjab',
    'Jammu y Cachemira': 'Jammu and Kashmir',
    
    # === Pakistan ===
    'Baluchist n': 'Balochistan', 
    'Jaiber Pajtunju': 'Khyber Pakhtunkhwa',

    # Southeast Asia
    # === Laos === 
    'Prefectura de Vienti n': 'Vientiane',

    # === Cambodia === 
    'Nom Pen': 'Phnom Penh', 
    
    # === Myanmar === 
    'Rang n': 'Yangon',
    'Rangún': 'Yangon',
    
    # === Vietnam ===
    'Ciudad Ho Chi Minh': 'Ho Chi Minh City',
    'D Nang': 'Da Nang',
    'T?nh C?n Th?': 'Can Tho',       
    'Th? D H N?i': 'Hanoi',
    'Kh nh H a': 'Khanh Hoa',
    'Ki n Giang': 'Kiên Giang',
    
    # === Singapore ===
    'Singapur': 'Singapore',

    # === Indonesia ===
    'Yakarta': 'DKI Jakarta',
    'Java Occidental': 'Jawa Barat',
    'Java Central': 'Jawa Tengah',
    'Java Oriental': 'Jawa Timur',
    'C lebes Central': 'Sulawesi Tengah',
    'C lebes Septentrional': 'Sulawesi Utara',
    'C lebes Suroriental': 'Sulawesi Tenggara',
    'Célebes Central': 'Sulawesi Tengah',      
    'Célebes Septentrional': 'Sulawesi Utara',  
    'Célebes Suroriental': 'Sulawesi Tenggara',
    'Sumatra Meridional': 'Sumatera Selatan',      
    'Sumatra Occidental': 'Sumatera Barat',       
    'Sumatra Septentrional': 'Sumatera Utara',   
    'Kalimantan Oriental': 'Kalimantan Timur',   
    'Borneo Occidental': 'Kalimantan Barat',     
    'Borneo Meridional': 'Kalimantan Selatan',    
    'Nusa Tenggara Oriental': 'Nusa Tenggara Timur', 
    'Nusatenggara Occidental': 'Nusa Tenggara Barat',
    
    # === Philippines ===
    'Luzón Central': 'Central Luzon',
    'Luz n Central': 'Central Luzon',
    'Calabarz n': 'Calabarzon',
    'Visayas Occidental': 'Western Visayas',
    'Mindanao Septentrional': 'Northern Mindanao',

    # =========================================================
    # OCEANIA
    # =========================================================
    'Australia Occidental': 'Western Australia',
    'Australia del Sur': 'South Australia',
    'Nueva Gales del Sur': 'New South Wales',
    'Territorio de la Capital Australiana': 'Australian Capital Territory',
    'Territorio del Norte': 'Northern Territory',

    # === Generic ===
    'Territorio de la Capital Federal': 'Federal Capital Territory',
    'Meridional': 'Southern',
    'Septentrional': 'Northern',
    'Occidental': 'Western',
    'Oriental': 'Eastern',
    'Noroeste': 'North West',
    'Sudeste': 'South East',
    'Sud': 'South',
    'Ouest': 'West',
    'Ouest del Sur': 'Southwest',
    'Est': 'East',
}

df['Order State'] = df['Order State'].astype(str).str.replace(r'\s+', ' ', regex=True).str.strip()
df['Order State'] = df['Order State'].replace(order_state_fixes)

df['order date (DateOrders)'] = pd.to_datetime(df['order date (DateOrders)'], format='mixed', dayfirst=True)
df['order date (DateOrders)'] = df['order date (DateOrders)'].dt.normalize()

df = df.drop(columns=['Order Zipcode']) # Menghapus kolom, karena terdapat data yang kosong ketimbang yang terisi!

print("Daftar order country pada dataset: ")
print(sorted(df['Order Country'].unique()))

print("\n")

print("Daftar order city pada dataset: ")
print(sorted(df['Order City'].unique()))

print("\n")

print("Daftar order state pada dataset: ")
print(sorted(df['Order State'].unique()))

print("\n")

print("Daftar order region pada dataset: ")
print(sorted(df['Order Region'].unique()))

print("\n")

print("Daftar order status pada dataset: ")
print(sorted(df['Order Status'].unique()))

# Mengecek Missing Values (data hilang) pada kolom dataset
print(f"Jumlah data yang hilang pada kolom Order Country di dataset: {df['Order Country'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Region di dataset: {df['Order Region'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order State di dataset: {df['Order State'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order City di dataset: {df['Order City'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Date di dataset: {df['order date (DateOrders)'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order ID di dataset: {df['Order Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Status di dataset: {df['Order Status'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Item ID di dataset: {df['Order Item Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Cardprod ID di dataset: {df['Order Item Cardprod Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Product Price di dataset: {df['Order Item Product Price'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Discount di dataset: {df['Order Item Discount'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Discount Rate di dataset: {df['Order Item Discount Rate'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Item Quantity di dataset: {df['Order Item Quantity'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Item Total di dataset: {df['Order Item Total'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Profit Ratio di dataset: {df['Order Item Profit Ratio'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Order Profit Per Order di dataset: {df['Order Profit Per Order'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Sales di dataset: {df['Sales'].isna().sum()}")

print("\n")

df.head(10)
# Out:
# Daftar order country pada dataset:
# ...

# %%
# Data Cleaning
# Bagian Product

df = df.drop(columns=['Product Description', 'Product Status'])

print("\n")

# Mengecek Missing Values (data hilang) pada kolom dataset
print(f"Jumlah data yang hilang pada kolom Product Card ID di dataset: {df['Product Card Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Product Category ID di dataset: {df['Product Category Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Product Image di dataset: {df['Product Image'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Product Name di dataset: {df['Product Name'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Product Price di dataset: {df['Product Price'].isna().sum()}")
# Out:
# Jumlah data yang hilang pada kolom Product Card ID di dataset: 0
# Jumlah data yang hilang pada kolom Product Category ID di dataset: 0
# Jumlah data yang hilang pada kolom Product Image di dataset: 0
# Jumlah data yang hilang pada kolom Product Name di dataset: 0
# Jumlah data yang hilang pada kolom Product Price di dataset: 0

# %%
# Data Cleaning 
# Bagian Sisanya

df['shipping date (DateOrders)'] = pd.to_datetime(df['shipping date (DateOrders)'], format='mixed', dayfirst=True)
df['shipping date (DateOrders)'] = df['shipping date (DateOrders)'].dt.normalize()

print("Daftar Shipping Mode pada dataset: ")
print(sorted(df['Shipping Mode'].unique()))

print("\n")

print("Daftar Category Name pada dataset: ")
print(sorted(df['Category Name'].unique()))

print("\n")

print("Daftar Market pada dataset: ")
print(sorted(df['Market'].unique()))

print("\n")

print("Daftar Type pada dataset: ")
print(sorted(df['Type'].unique()))

print("\n")

print(f"Jumlah data yang hilang pada kolom Department ID di dataset: {df['Department Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Department Name di dataset: {df['Department Name'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Shipping Date di dataset: {df['shipping date (DateOrders)'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Shipping Mode di dataset: {df['Shipping Mode'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Days Shipping di dataset: {df['Days for shipping (real)'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Days Shipment di dataset: {df['Days for shipment (scheduled)'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Benefit Order di dataset: {df['Benefit per order'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Sales Customer di dataset: {df['Sales per customer'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Delivery Status di dataset: {df['Delivery Status'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Delivery Risk di dataset: {df['Late_delivery_risk'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Category ID di dataset: {df['Category Id'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Category Name di dataset: {df['Category Name'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Latitude di dataset: {df['Latitude'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Longitude Name di dataset: {df['Longitude'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Market Name di dataset: {df['Market'].isna().sum()}")
print(f"Jumlah data yang hilang pada kolom Type di dataset: {df['Type'].isna().sum()}")
# Out:
# Daftar Shipping Mode pada dataset:
# ['First Class', 'Same Day', 'Second Class', 'Standard Class']
#
#
# Daftar Category Name pada dataset:
# ['Accessories', 'As Seen on  TV!', 'Baby ', 'Baseball & Softball', 'Basketball', 'Books ', 'Boxing & MMA', 'CDs ', 'Cameras ', 'Camping & Hiking', 'Cardio Equipment', "Children's Clothing", 'Cleats', 'Computers', 'Consumer Electronics', 'Crafts', 'DVDs', 'Electronics', 'Fishing', 'Fitness Accessories', 'Garden', "Girls' Apparel", 'Golf Apparel', 'Golf Bags & Carts', 'Golf Balls', 'Golf Gloves', 'Golf Shoes', 'Health and Beauty', 'Hockey', 'Hunting & Shooting', 'Indoor/Outdoor Games', "Kids' Golf Clubs", 'Lacrosse', "Men's Clothing", "Men's Footwear", "Men's Golf Clubs", 'Music', 'Pet Supplies', 'Shop By Sport', 'Soccer', 'Sporting Goods', 'Strength Training', 'Tennis & Racquet', 'Toys', 'Trade-In', 'Video Games', 'Water Sports', "Women's Apparel", "Women's Clothing", "Women's Golf Clubs"]
#
#
# Daftar Market pada dataset:
# ...

# %%
# Konversi ke CSV
df.to_csv('data_clean/clean_DataCoSupply_Chain.csv', index=False)
