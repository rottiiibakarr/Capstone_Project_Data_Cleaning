# %%
import pandas as pd

# %%
df = pd.read_csv('data_raw/DataCoSupplyChainDataset.csv', encoding='latin1')
df.columns = df.columns.str.strip()

# %%
# Mengecek Duplikat, Jumlah Data pada Dataset, dan Info
print(f'Total baris duplikat: {df.duplicated().sum()}')
df.drop_duplicates(inplace=True)
print(f'Total baris setelah menghapus duplikat: {df.duplicated().sum()}')

print(f'Total data pada dataset Attendance: {df.shape} [baris, kolom]')

df.info()
# Out:
# Total baris duplikat: 0
# Total baris setelah menghapus duplikat: 0
# Total data pada dataset Attendance: (180519, 53) [baris, kolom]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB

# %%
# Data Cleaning
state_mapping = {
    'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 
    'CO': 'Colorado', 'CT': 'Connecticut', 'DC': 'District of Columbia', 
    'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 
    'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 
    'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'MA': 'Massachusetts', 
    'MD': 'Maryland', 'MI': 'Michigan', 'MN': 'Minnesota', 'MO': 'Missouri', 
    'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota', 
    'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada', 'NY': 'New York', 
    'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 
    'PR': 'Puerto Rico', 'RI': 'Rhode Island', 'SC': 'South Carolina', 
    'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia', 
    'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia',
    
    # Memperbaiki data yang salah berdasarkan kodepos
    '91732': 'California', # Zip code untuk area El Monte, CA
    '95758': 'California'  # Zip code untuk area Elk Grove, CA
}

order_state_fixes = {
    # =========================================================
    # AMERICA (NORTH, CENTRAL, SOUTH)
    # =========================================================

    # --- North America ---
    # === Canada ===
    'Columbia brit nica': 'British Columbia',
    'Nueva Escocia': 'Nova Scotia',
    
    # === United States of America ===
    'Nueva York': 'New York',
    'Nueva Jersey': 'New Jersey',
    'Nuevo Hampshire': 'New Hampshire',
    'Nuevo México': 'New Mexico',
    'Carolina del Norte': 'North Carolina',
    'Carolina del Sur': 'South Carolina',
    'Dakota del Norte': 'North Dakota',
    'Dakota del Sur': 'South Dakota',
    'Distrito de Columbia': 'District of Columbia',
    'Virginia Occidental': 'West Virginia',
    'Columbia Británica': 'British Columbia',
    'Nueva Escocia': 'Nova Scotia',
    'Oreg n': 'Oregon',

    # --- Central America & Caribbean ---
    # === Mexico ===
    'Nuevo Le n': 'Nuevo León',
    'M xico': 'México',
    'Michoac n': 'Michoacán',
    'Yucat n': 'Yukatan',
    'Quer taro': 'Querétaro',
    'San Luis Potos ': 'San Luis Potosí',

    # === El Salvador ===
    'Cuscatl n': 'Cuscatlán',
    
    # === Dominican Republic ===
    'Monse or Nouel': 'Monseñor Nouel',
    'San Pedro de Macor s': 'San Pedro de Macoris',

    # === Honduras ===
    'Francisco Moraz n': 'Francisco Morazán', # Department
    'Cort s': 'Cortés',
    'Col n': 'Colón',
    'Atl ntida': 'Atlántida',

    # === Panama === 
    'Col n': 'Colón',
    'Chiriqu': 'Chiriquí',
    
    # === Cuba ===
    'Holgu n': 'Holguín',
    'Pinar del R o': 'Pinar del Río',
    'Camag ey': 'Camagüey',
    'Ciego de vila': 'Ciego de Ávila',
    'Sancti Sp ritus': 'Sancti Spíritus',
    'Guant namo': 'Guantánamo',

    # === Nicaragua ===
    'Estel': 'Estelí',

    # --- South American ---
    # === Colombia === 
    'Antioqu a': 'Antioquia',
    'Quind o': 'Quindío',
    'Nari o': 'Nariño',
    'Atl ntico': 'Atlántico',
    'Bogot': 'Bogotá',
    'Boyac': 'Boyacá',
    'Caquet': 'Caquetá',
    'Choc': 'Chocó',
    
    # === Venezuela ===
    'Anzo tegui': 'Anzoátegui',
    'Bol var': 'Bolívar',
    'M rida': 'Mérida',
    'T chira': 'Táchira',
    'Regi n Capital': 'Capital Region',
    'Gu rico': 'Guárico',

    # === Guyana ===
    'Demerara-Berbice Superior': 'Upper Demerara-Berbice',
    
    # === Brazil ===
    'Bah a': 'Bahía',
    'Goi s': 'Goiás',
    'Amap ': 'Amapá',
    'Mara n': 'Maranhão',
    'Río de Janeiro': 'Rio de Janeiro',
    'R o de Janeiro': 'Rio de Janeiro',
    'Río Grande del Norte': 'Rio Grande do Norte',
    'R o Grande del Norte': 'Rio Grande do Norte',
    'Mato Grosso del Sur': 'Mato Grosso do Sul',
    'S o Paulo': 'São Paulo',
    'Esp ritu Santo': 'Espírito Santo',
    'Para ba': 'Paraíba',
    'Cear': 'Ceará',
    
    # === Paraguay ===
    'Asunci n': 'Asunción',

    # === Chile ===
    'B o-B o': 'Bío-Bío',
    'Magallanes y Ant rtica Chilena': 'Magallanes and Chilean Antarctica',
    'Valpara so': 'Valparaíso',

    # === Peru ===
    'Jun n': 'Junín',
    
    # === Argentina ===
    'C rdoba': 'Córdoba',
    'Neuqu n': 'Neuquén',
    'Entre R os': 'Entre Ríos',
    'R os': 'Río Tala',
    'Río Negro': 'Rio Negro',
    'R o Negro': 'Rio Negro',

    # =========================================================
    # EUROPEAN
    # =========================================================

    # === Ireland ===
    'Dubl n': 'Dublin',

    # === United Kingdom (UK) ===
    'Gales': 'Wales',
    'Inglaterra': 'England',
    'Escocia': 'Scotland',
    
    # === Sweden ===
    'V rmland': 'Värmland',
    'V stra G taland': 'Västra Götaland',
    'Estocolmo': 'Stockholm',
    
    # === France ===
    'Auvernia-R dano-Alpes': 'Auvergne-Rhône-Alpes',
    'Alsacia-Champa a-Ardenas-Lorena': 'Grand Est',
    'Borgoña-Franco Condado': 'Bourgogne-Franche-Comté',
    'Breta a': 'Brittany',
    'Bretaña': 'Brittany',
    'Norte-Paso de Calais-Picard a': 'Hauts-de-France',
    'Normand a': 'Normandy',
    'Normandía': 'Normandy',
    'Isla de Francia': 'Île-de-France',
    'Países del Loira': 'Pays de la Loire',

    # === Switzerland ===
    'Zúrich': 'Zürich',
    'Basilea-Ciudad': 'Basel-Stadt',
    
    # === Italy ===
    'Lombard a': 'Lombardy',
    'Emilia-Roma a': 'Emilia-Romagna',
    'Cerde a': 'Sardinia',
    'Umbr a': 'Umbria',
    
    # === Spain ===
    'Catalu a': 'Catalonia',
    'Cataluña': 'Catalonia',
    'Andaluc a': 'Andalusia',
    'Andalucía': 'Andalusia',
    'Le n': 'León',
    'Castilla y Le n': 'Castilla and León',
    'Islas Baleares': 'Illes Balears',

    # === Netherlands ===
    'Holanda Meridional': 'South Holland',
    'Holanda Septentrional': 'Noord-Holland',
    'G eldres': 'Gelderland',

    # === Denmark ===
    'Dinamarca Meridional': 'Region of Southern Denmark',

    # === Germany ===
    'Baja Sajonia': 'Lower Saxony',
    'Berl n': 'Berlin',
    'Renania del Norte-Westfalia': 'North Rhine-Westphalia',
    'Mecklemburgo-Pomerania Occidental': 'Mecklenburg-Vorpommern',

    # === Austria ===
    'Alta Austria': 'Upper Austria',

    # === Czechia ===
    'Hradec Kr lov ': 'Hradec Králové',
    'Hradec Kr lov': 'Hradec Králové',
    'st nad Labem': 'Ústí nad Labem',
    
    # === Slovakia ===
    'Bansk Bystrica': 'Banská Bystrica',
    'ilina': 'Žilina',
    
    # === Hungary ===
    'B k s': 'Békés',
    'Hajd -Bihar': 'Hajdú-Bihar',
    'Gy?r': 'Győr',

    # === Belgium ===
    'Flanders Occidental': 'West Flanders',
    'Flanders Oriental': 'East Flanders',

    # === Albania ===
    'Durr s': 'Durrës',
    'Shkod r': 'Shkodër',

    # === Lithuania ===
    'iauliai': 'Šiauliai',
    
    # === Belarus ===
    'G mel': 'Gomel',
    
    # === Russia ===
    'Bashkortost n': 'Bashkortostan',
    'Daguest n': 'Dagestan',
    'Astrac n': 'Astrakhan',
    'B lgorod': 'Belgorod',
    'Cheli binsk': 'Chelyabinsk',
    'N vgorod': 'Novgorod',
    'Vlad mir': 'Vladimir',
    'Vor nezh': 'Voronezh',
    'Mosc': 'Moscow',
    'Arj nguelsk': 'Arkhangelsk',

    # === Ukraine ===
    'J rkov': 'Kharkiv',
    'Tern pil': 'Ternopil',
    'V nnytsia': 'Vinnytsia',
    'Zhyt myr': 'Zhytomyr',
    'Jers n': 'Kherson',

    # === Moldova ===
    'Chisin u': 'Chișinău',
    
    # === Romania ===
    'V lcea': 'Vâlcea',
    'Bra?ov': 'Brașov',

    # =========================================================
    # AFRICA
    # =========================================================

    # === South Africa ===
    'Cabo Occidental': 'Western Cape', 
    'Cabo Oriental': 'Eastern Cape',

    # === Algeria ===
    'Or n': 'Oran',                  
    'Bug a': 'Bejaia',
    'B char': 'Béchar',

    # === Benin ===
    'Ou m': 'Ouémé',

    # === Guinea-Bissau ===
    'Bis u': 'Bissau',

    # === Morocco === 
    'Fez-Bulm n': 'Fas Bulman',   
    'T nger-Tetu n': 'Tangier-Tétouan',
    'Chau a-Uardiga': 'Chaouia-Ouardigha',

    # === Western Sahara ===
    'El Aai n': 'El Aaiún',

    # === Egypt ===
    'Alejandr a': 'Alexandria',
    'Alejandría': 'Alexandria',
    'Fay n': 'Al Fayyum',                
    'Puerto Sa d': 'Bursaid',

    # === Senegal ===
    'Thi s': 'Thiès',

    # === Democratic Republic of Congo ===
    'quateur': 'Équateur',

    # =========================================================
    # ASIA (Central, West, East, South, Southeast)
    # =========================================================

    # Central Asia
    # === Kazakhstan ===
    'Kostan i': 'Kostanay',
    'Ciudad de Almat': 'Almaty',
    'Ciudad de Almaty': 'Almaty',

    # === Uzbekistan === 
    'Namang n': 'Namangan',          
    'Andij n': 'Andijan',            
    'Surjandar n': 'Surxondaryo',

    # === Turkmenistan ===
    'Asjabad': 'Ashgabat',

    # West Asia (Middle East)
    # === Turkey ===
    'Bing l': 'Bingöl',
    'D zce': 'Düzce',                
    'K tahya': 'Kütahya',
    'Estambul': 'Istanbul',
    'anakkale': 'Çanakkale',

    # === Iran ===
    'Juzest n': 'Khuzestan',          
    'Isfah n': 'Isfahan',            
    'Hamad n': 'Hamedan',            
    'Teher n': 'Teheran',            
    'Guil n': 'Gīlān',              
    'Zany n': 'Zanjan',              
    'Sist n y Baluchist n': 'Sistan and Baluchestan',
    'Mazandar n': 'Māzandarān',      
    'Qazv n': 'Qazvin',              
    'Golest n': 'Golestán',          
    'Semn n': 'Semnan',              
    'Hormozg n': 'Hormozgān',

    # === Iraq === 
    'N nive': 'Nineveh',
    'Kurdist n': 'Kurdistan',

    # === Jordan ===
    'Am n': 'Amman',

    # === Israel === 
    'Jerusal n': 'Jerusalem', 

    # === Saudi Arabian === 
    'Jiz n': 'Jizan',

    # United Arab Emirates
    'Ajm n': 'Ajmān',

    # East Asia
    # === Mongolia ===
    'Ulán Bator': 'Ulaanbaatar',     
    'Ul n Bator': 'Ulaanbaatar',
    
    # === China ===
    'Pek n': 'Peking',
    'Pekín': 'Beijing',
    'Shangh i': 'Shanghai',
    'Shanghái': 'Shanghai',
    
    # === Taiwan ===
    'Taip i': 'Taipei',
    
    # === South Korea ===
    'Se l': 'Seoul',
    'Seúl': 'Seoul',
    
    # South Asia
    # === India ===
    'Rajast n': 'Rajasthan',
    'Bengala Occidental': 'West Bengal',
    'Capital Nacional': 'National Capital Territory',
    
    # === Pakistan ===
    'Baluchist n': 'Balochistan', 

    # Southeast Asia
    # === Laos === 
    'Prefectura de Vienti n': 'Vientiane',
    
    # === Myanmar === 
    'Rang n': 'Yangon',
    'Rangún': 'Yangon',
    
    # === Vietnam ===
    'Ciudad Ho Chi Minh': 'Ho Chi Minh',
    'D Nang': 'Da Nang',             
    'T?nh C?n Th?': 'Can Tho',       
    'Th? D H N?i': 'Hanoi',
    'Kh nh H a': 'Khanh Hoa',
    'Ki n Giang': 'Kiên Giang',

    # === Singapore ===
    'Singapur': 'Singapore',

    # === Indonesia ===
    'Java Occidental': 'Jawa Barat',
    'Java Central': 'Jawa Tengah',
    'Java Oriental': 'Jawa Timur',
    'C lebes Central': 'Sulawesi Tengah',
    'C lebes Septentrional': 'Sulawesi Utara',
    'C lebes Suroriental': 'Sulawesi Tenggara',
    'Célebes Central': 'Sulawesi Tengah',      
    'Célebes Septentrional': 'Sulawesi Utara',  
    'Célebes Suroriental': 'Sulawesi Tenggara',
    'Sumatra Meridional': 'Sumatera Selatan',      
    'Sumatra Occidental': 'Sumatera Barat',       
    'Sumatra Septentrional': 'Sumatera Utara',   
    'Kalimantan Oriental': 'Kalimantan Timur',   
    'Borneo Occidental': 'Kalimantan Barat',     
    'Borneo Meridional': 'Kalimantan Selatan',    
    'Nusa Tenggara Oriental': 'Nusa Tenggara Timur', 
    'Nusatenggara Occidental': 'Nusa Tenggara Barat',
    
    # === Philippines ===
    'Luzón Central': 'Luzon',
    'Luz n Central': 'Central Luzon',
    'Calabarz n': 'Calabarzon',
    'Visayas Occidental': 'Western Visayas',
    'Mindanao Septentrional': 'Northern Mindanao',

    # =========================================================
    # OCEANIA
    # =========================================================
    'Australia Occidental': 'Western Australia',
    'Australia del Sur': 'South Australia',
}

df['Customer Country'] = df['Customer Country'].replace({'EE. UU.': 'United States of America'})

df['Customer State'] = df['Customer State'].map(state_mapping).fillna(df['Customer State'])

df['Order State'] = df['Order State'].replace(order_state_fixes)
df['Order State'] = df['Order State'].astype(str).str.replace(r'\s+', ' ', regex=True).str.strip()

print("Nama negara pada dataset: ")
print(sorted(df['Customer Country'].unique()))

print("Daftar nama negara bagian Amerika Serikat pada dataset: ")
print(sorted(df['Customer State'].unique()))

print("Daftar wilayah pesanan pada dataset: ")
print(sorted(df['Order State'].unique()))

print("Daftar nama wilayah pesanan pada dataset: ")
print(sorted(df['Order Region'].unique()))

df.head(20)
# Out:
# Nama negara pada dataset:
# ['Puerto Rico', 'United States of America']
# Daftar nama negara bagian Amerika Serikat pada dataset:
# ['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'Montana', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']
# Daftar wilayah pesanan pada dataset:
# ['Abia', 'Abruzos', 'Aceh', 'Acre', 'Adamaoua', 'Adamawa', 'Adana', 'Adiyaman', 'Afyonkarahisar', 'Aichi', 'Ajmān', 'Akmola', 'Aksaray', 'Akwa Ibom', 'Al Asimah', 'Al Bahr al Ahmar', 'Al Buhayrah', 'Al Fayyum', 'Al Hudayda', 'Al Jawf', 'Al Marqab', 'Alabama', 'Alagoas', 'Alberta', 'Alexandria', 'Alger', 'Alibori', 'Almaty', 'Amapá', 'Amasya', 'Amazonas', 'Amberes', 'Amman', 'Amur', 'Analamanga', 'Anambra', 'Ancash', 'Andalusia', 'Andhra Pradesh', 'Andijan', 'Anhui', 'Ankara', 'Annaba', 'Anseba', 'Antalya', 'Antioquia', 'Antofagasta', 'Anzoátegui', 'Aomori', 'Apulia', 'Aquitania-Lemos n-Poitou-Charentes', 'Ar Raqa', 'Arad', 'Aragua', 'Arauca', 'Arbil', 'Ardahan', 'Ardebil', 'Arequipa', 'Arges', 'Arica y Parinacota', 'Arizona', 'Arkansas', 'Arkhangelsk', 'Artemisa', 'Artibonito', 'Arusha', 'Ash Sharqiyah', 'Ashanti', 'Ashgabat', 'Asir', 'Asiut', 'Assam', 'Astan', 'Astrakhan', 'Asturias', 'Asunción', 'Aswan', 'Atacama', 'Atakora', 'Atlántico', 'Atlántida', 'Atsimo-Andrefana', 'Atsinanana', 'Attica', 'Auckland', 'Auvergne-Rhône-Alpes', 'Auvernia', 'Aveiro', 'Ayacucho', 'Aydin', 'Azuay', 'Babilonia', 'Bacau', 'Baden-Wurtemberg', 'Bagdad', 'Bahía', 'Baja California', 'Baja California Sur', 'Bajo Congo', 'Baki', 'Bali', 'Balikesir', 'Balochistan', 'Balti', 'Bamako', 'Bandundu', 'Bangkok', 'Bangui', 'Bani Suwayf', 'Bansk Bystrica', 'Barahona', 'Basel-Stadt', 'Bashkortostan', 'Basilicata', 'Basora', 'Batman', 'Batna', 'Bauchi', 'Bavaria', 'Bay of Plenty', 'Beirut', 'Bejaia', 'Belgorod', 'Benadir', 'Bengasi', 'Bengkulu', 'Benguela', 'Benue', 'Berlin', 'Berna', 'Bi', 'Bihar', 'Bihor', 'Bingöl', 'Bishkek', 'Bissau', 'Bistrita-Nasaud', 'Bitola', 'Boeny', 'Bogot', 'Bolu', 'Bolívar', 'Borgo a-Franco Condado', 'Borgou', 'Borno', 'Botosani', 'Boyac', 'Brabante Flamenco', 'Brabante Septentrional', 'Braga', 'Braila', 'Brandenburgo', 'Brașov', 'Bremen', 'Brest', 'Briansk', 'British Columbia', 'Brittany', 'Bruselas', 'Budapest', 'Buenos Aires', 'Buenos Aires (provincia)', 'Bulawayo', 'Burgas', 'Bursa', 'Bursaid', 'Busan', 'Bushehr', 'Buskerud', 'Buyumbura Mairie', 'Buzau', 'Béchar', 'Békés', 'Bío-Bío', 'Cabo Delgado', 'Cadisia', 'Cajamarca', 'Calabarzon', 'Calabria', 'Caldas', 'California', 'Callao', 'Camagüey', 'Campania', 'Campeche', 'Can Tho', 'Canelones', 'Cantabria', 'Canterbury', 'Capital Region', 'Caquet', 'Carabobo', 'Caras-Severin', 'Carintia', 'Casanare', 'Castilla and León', 'Castilla-La Mancha', 'Catalonia', 'Catamarca', 'Cear', 'Central', 'Central Luzon', 'Centro', 'Centro-Valle de Loira', 'Cesar', 'Ceuta', 'Chaco', 'Chaguanas', 'Chandigarh', 'Chaouia-Ouardigha', 'Chelyabinsk', 'Cherkasy', 'Chernihiv', 'Chhattisgarh', 'Chiapas', 'Chiba', 'Chihuahua', 'Chimaltenango', 'Chinandega', 'Chiriqu', 'Chittagong', 'Chișinău', 'Choc', 'Choluteca', 'Chongqing', 'Chubut', 'Chukha', 'Chungcheong del Sur', 'Chuquisaca', 'Cidade De Maputo', 'Ciego de vila', 'Cienfuegos', 'Ciudad de Almat', 'Cluj', 'Coahuila', 'Cochabamba', 'Coimbra', 'Cojedes', 'Colima', 'Colorado', 'Colón', 'Connecticut', 'Constantina', 'Constanza', 'Copperbelt', 'Cordillera', 'Cork', 'Corrientes', 'Corse', 'Cortés', 'Corum', 'Costa', 'Cross River', 'Cundinamarca', 'Cuscatlán', 'Córdoba', 'D Nang', 'Daca', 'Daegu', 'Daejeon', 'Dagestan', 'Dakar', 'Dar es Salaam', 'Dayr az Zawr', 'Delaware', 'Delhi', 'Delta', 'Denizli', 'Departamento Atl ntico', 'Di Car', 'Diala', 'Diana', 'Diffa', 'Dire Dawa', 'District of Columbia', 'Distrito Capital', 'Distrito Federal', 'Distrito de Cayo', 'Dix-Huit Montagnes', 'Diyarbakir', 'Djelfa', 'Dnipropetrovsk', 'Doha', 'Dolj', 'Donetsk', 'Donga', 'Drenthe', 'Duarte', 'Dubl n del Sur', 'Dublin', 'Dukala-Abda', 'Durango', 'Durrës', 'Düzce', 'East Flanders', 'Eastern Cape', 'Ebonyi', 'Ecuatoria Central', 'Edo', 'El Aaiún', 'El Beni', 'El Cairo', 'Elazig', 'Elbasan', 'Emilia-Romagna', 'England', 'Entre Ríos', 'Enugu', 'Erzurum', 'Escania', 'Escuintla', 'Eskisehir', 'Espaillat', 'Espírito Santo', 'Est', 'Estado Libre', 'Estel', 'Estuaire', 'Extremadura', 'Ext ...
# Daftar nama wilayah pesanan pada dataset:
# ['Canada', 'Caribbean', 'Central Africa', 'Central America', 'Central Asia', 'East Africa', 'East of USA', 'Eastern Asia', 'Eastern Europe', 'North Africa', 'Northern Europe', 'Oceania', 'South America', 'South Asia', 'South of  USA ', 'Southeast Asia', 'Southern Africa', 'Southern Europe', 'US Center ', 'West Africa', 'West Asia', 'West of USA ', 'Western Europe']
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0      DEBIT                         3                              4
# 1   TRANSFER                         5                              4
# 2       CASH                         4                              4
# 3      DEBIT                         3                              4
# 4    PAYMENT                         2                              4
# 5   TRANSFER                         6                              4
# 6      DEBIT                         2                              1
# 7   TRANSFER                         2                              1
# 8       CASH                         3                              2
# 9       CASH                         2                              1
# 10  TRANSFER                         6                              2
# 11  TRANSFER                         5                              2
# 12  TRANSFER                         4                              2
# 13     DEBIT                         2                              1
# 14  TRANSFER                         2                              1
# 15     DEBIT                         2                              1
# 16   PAYMENT                         5                              2
# 17      CASH                         2                              1
# 18     DEBIT                         2                              1
# 19   PAYMENT                         0                              0
#
#     Benefit per order  Sales per customer    Delivery Status  \
# 0           91.250000          314.640015   Advance shipping
# 1         -249.089996          311.359985      Late delivery
# 2         -247.779999          309.720001   Shipping on time
# 3           22.860001          304.809998   Advance shipping
# 4          134.210007          298.250000   Advance shipping
# 5           18.580000          294.980011  Shipping canceled
# 6           95.180000          288.420013      Late delivery
# 7           68.430000          285.140015      Late delivery
# 8          133.720001          278.589996      Late delivery
# 9          132.149994          275.309998      Late delivery
# 10         130.580002          272.029999  Shipping canceled
# 11          45.689999          268.760010      Late delivery
# 12          21.760000          262.200012      Late delivery
# 13          24.580000          245.809998      Late delivery
# 14          16.389999          327.750000      Late delivery
# 15        -259.579987          324.470001      Late delivery
# 16        -246.360001          321.200012      Late delivery
# 17          23.840000          317.920013      Late delivery
# 18         102.260002          314.640015      Late delivery
# 19          87.180000          311.359985   Shipping on time
#
#     Late_delivery_risk  Category Id   Category Name   Customer City  ...  \
# 0                    0           73  Sporting Goods          Caguas  ...
# 1                    1           73  Sporting Goods          Caguas  ...
# 2                    0           73  Sporting Goods        San Jose  ...
# 3                    0           73  Sporting Goods     Los Angeles  ...
# 4                    0           73  Sporting Goods          Caguas  ...
# 5                    0           73  Sporting Goods       Tonawanda  ...
# 6                    1           73  Sporting Goods          Caguas  ...
# 7                    1           73  Sporting Goods           Miami  ...
# 8                    1           73  Sporting Goods          Caguas  ...
# 9                    1           73  Sporting Goods       San Ramon  ...
# 10                   0           73  Sporting Goods          Caguas  ...
# 11                   1           73  Sporting Goods        Freeport  ...
# 12                   1           73  Sporting Goods         Salinas  ...
# 13                   1           73  Sporting Goods          Caguas  ...
# 14                   1           73  Sporting Goods         Peabody  ...
# 15                   1           73  Sporting Goods          Caguas  ...
# 16                   1           73  Sporting Goods       Canovanas  ...
# 17                   1           73  Sporting Goods       Paramount  ...
# 18                   1           73  Sporting Goods          Caguas  ...
# 19                   0           73  Sporting Goods  Mount Prospect  ...
#
#    Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0            NaN            1360                  73                  NaN
# 1            NaN            1360                  73                  NaN
# 2            NaN            1360                  73                  NaN
# 3            NaN            1360                  73                  NaN
# 4            NaN            1360                  73                  NaN
# 5            NaN            1360                  73                  NaN
# 6            NaN            1360                  73                  NaN
# 7            NaN            1360                  73                  NaN
# 8            NaN            1360                  73                  NaN
# 9            NaN            1360                  73                  NaN
# 10           NaN            1360                  73                  NaN
# 11           NaN            1360                  73                  NaN
# 12           NaN            1360                  73                  NaN
# 13           NaN            1360                  73                  NaN
# 14           NaN            1360                  73                  NaN
# 15           NaN            1360                  73                  NaN
# 16           NaN            1360                  73                  NaN
# 17           NaN            1360                  73                  NaN
# 18           NaN            1360                  73                  NaN
# 19           NaN            1360                  73                  NaN
#
#                                    Product Image  Product Name Product Price  \
# 0   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 5   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 6   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 7   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 8   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 9   http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 10  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 11  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 12  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 13  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 14  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 15  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 16  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 17  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 18  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 19  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#    Product Status shipping date (DateOrders)   Shipping Mode
# 0               0             2/3/2018 22:56  Standard Class
# 1               0            1/18/2018 12:27  Standard Class
# 2               0            1/17/2018 12:06  Standard Class
# 3               0            1/16/2018 11:45  Standard Class
# 4               0            1/15/2018 11:24  Standard Class
# 5               0            1/19/2018 11:03  Standard Class
# 6               0            1/15/2018 10:42     First Class
# 7               0            1/15/2018 10:21     First Class
# 8               0            1/16/2018 10:00    Second Class
# 9               0             1/15/2018 9:39     First Class
# 10              0             1/19/2018 9:18    Second Class
# 11              0             1/18/2018 8:57    Second Class
# 12              0             1/17/2018 8:36    Second Class
# 13              0             1/15/2018 8:15     First Class
# 14              0             1/15/2018 7:54     First Class
# 15              0             1/15/2018 7:33     First Class
# 16              0             1/18/2018 7:12    Second Class
# 17              0             1/15/2018 6:51     First Class
# 18              0             1/15/2018 6:30     First Class
# 19              0            1/13/2018 18:09        Same Day
#
# [20 rows x 53 columns]

# %%
# Konversi ke CSV
df.to_csv('data_clean/clean_DataCoSupply_Chain.csv', index=False)
